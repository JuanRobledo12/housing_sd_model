# %%
import mesa

# %%
help(mesa.space.NetworkGrid)
# Out:
# Help on class NetworkGrid in module mesa.space:
#
# class NetworkGrid(builtins.object)
#  |  NetworkGrid(g: 'Any') -> 'None'
#  |
#  |  Network Grid where each node contains zero or more agents.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, g: 'Any') -> 'None'
#  |      Create a new network.
#  |
#  |      Args:
#  |          g: a NetworkX graph instance.
#  |
#  |  get_all_cell_contents(self) -> 'list[Agent]'
#  |      Returns a list of all the agents in the network.
#  |
#  |  get_cell_list_contents(self, cell_list: 'list[int]') -> 'list[Agent]'
#  |      Returns a list of the agents contained in the nodes identified in `cell_list`.
#  |
#  |      Nodes with empty content are excluded.
#  |
#  |      Args:
#  |          cell_list: list of cell ids.
#  |
#  |      Returns:
#  |          list of the agents contained in the nodes identified in `cell_list`.
#  |
#  |  get_neighborhood(self, node_id: 'int', include_center: 'bool' = False, radius: 'int' = 1) -> 'list[int]'
# ...
